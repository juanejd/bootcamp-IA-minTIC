# %% [markdown]
# ## importar librerias

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## cargar CSV

# %%
dataset = pd.read_csv("Tarifas_aplicadas_de_Gas_Natural_20250813.csv")
dataset.head()
# Out:
#     ANO  MES                         EMPRESA  \
# 0  2023   10  EFIGAS GAS NATURAL S.A. E.S.P.
# 1  2023   10  EFIGAS GAS NATURAL S.A. E.S.P.
# 2  2023   10  EFIGAS GAS NATURAL S.A. E.S.P.
# 3  2023   10  EFIGAS GAS NATURAL S.A. E.S.P.
# 4  2023   10  EFIGAS GAS NATURAL S.A. E.S.P.
#
#                                           MUNICIPIOS         NIT  ID MERCADO  \
# 0  BALBOA - DOSQUEBRADAS - LA CELIA - LA VIRGINIA...  8002023953         167
# 1  CHINCHINA - MANIZALES - NEIRA - PALESTINA - VI...  8002023953         168
# 2  AGUADAS - ANSERMA - ARANZAZU - BELALCAZAR - PA...  8002023953         107
# 3  ARMENIA - CALARCA - CIRCASIA - FILANDIA - LA T...  8002023953         166
# 4  ARMENIA - CALARCA - CIRCASIA - FILANDIA - LA T...  8002023953         166
#
#    ID_EMPRESA  ESTRATO  CONEXION  REINSTALACION  RECONEXION  CARGO_FIJO  \
# 0        1887        1  718800.0       222500.0     51000.0         0.0
# 1        1887        1  718800.0       222500.0     51000.0         0.0
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 165360 entries, 0 to 165359
# Data columns (total 14 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   ANO            165360 non-null  int64
#  1   MES            165360 non-null  int64
#  2   EMPRESA        165360 non-null  object
#  3   MUNICIPIOS     165360 non-null  object
#  4   NIT            165360 non-null  int64
#  5   ID MERCADO     165360 non-null  int64
#  6   ID_EMPRESA     165360 non-null  int64
#  7   ESTRATO        165360 non-null  int64
#  8   CONEXION       165360 non-null  float64
#  9   REINSTALACION  165360 non-null  float64
#  10  RECONEXION     165360 non-null  float64
#  11  CARGO_FIJO     165360 non-null  float64
#  12  RANGO_0        165360 non-null  float64
#  13  RANGO_21       165360 non-null  float64
# dtypes: float64(6), int64(6), object(2)
# memory usage: 17.7+ MB

# %%
dataset.describe()
# Out:
#                  ANO            MES           NIT     ID MERCADO  \
# count  165360.000000  165360.000000  1.653600e+05  165360.000000
# mean     2016.445549       6.491570  8.534958e+09     133.489375
# std         4.579813       3.422467  4.191090e+08     155.417586
# min      2004.000000       1.000000  8.000078e+09       9.000000
# 25%      2014.000000       4.000000  8.040028e+09      37.000000
# 50%      2017.000000       7.000000  8.901017e+09     103.000000
# 75%      2020.000000       9.000000  8.909050e+09     167.000000
# max      2023.000000      12.000000  9.010428e+09    1825.000000
#
#           ID_EMPRESA        ESTRATO      CONEXION  REINSTALACION  \
# count  165360.000000  165360.000000  1.653600e+05   1.653600e+05
# mean     4670.692846       3.360414  5.743195e+05   1.840359e+05
# std      8519.143819       1.692553  1.705539e+05   1.375608e+05
# min       484.000000       1.000000  0.000000e+00   0.000000e+00
# ...
